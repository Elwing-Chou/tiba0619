# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tiba0619/blob/main/tsne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler

from sklearn.datasets import load_iris

data = load_iris()
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(data["data"])
tsne = TSNE(n_components=2, n_jobs=-1)
data_tsne = tsne.fit_transform(data_scale)
data_tsne

# %%
import matplotlib.pyplot as plt
import seaborn as sns
xs = data_tsne[:, 0]
ys = data_tsne[:, 1]
sns.scatterplot(x=xs,
        y=ys,
        hue=data["target"])
# Out:
# <Axes: >

# %%
from sklearn.datasets import load_wine
data = load_wine()
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(data["data"])
tsne = TSNE(n_components=2, n_jobs=-1)
data_tsne = tsne.fit_transform(data_scale)
xs = data_tsne[:, 0]
ys = data_tsne[:, 1]
sns.scatterplot(x=xs,
        y=ys,
        hue=data["target"])
# Out:
# <Axes: >

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(data["data"])
tsne = TSNE(n_components=2, n_jobs=-1)
data_tsne = tsne.fit_transform(data_scale)
xs = data_tsne[:, 0]
ys = data_tsne[:, 1]
sns.scatterplot(x=xs,
        y=ys,
        hue=data["target"])
# Out:
# <Axes: >

# %%
# https://seaborn.pydata.org/tutorial/color_palettes.html
from sklearn.datasets import load_digits
data = load_digits()
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(data["data"])
tsne = TSNE(n_components=2, n_jobs=-1)
data_tsne = tsne.fit_transform(data_scale)
xs = data_tsne[:, 0]
ys = data_tsne[:, 1]
sns.scatterplot(x=xs,
        y=ys,
        hue=data["target"],
        palette=sns.color_palette("hls", 10))
# Out:
# <Axes: >
